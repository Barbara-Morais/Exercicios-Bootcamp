# %% [markdown]
# <a href="https://colab.research.google.com/github/Barbara-Morais/Exercicios-Bootcamp/blob/main/node2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install node2vec
# Out:
# Collecting node2vec
#   Downloading node2vec-0.4.3.tar.gz (4.6 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from node2vec) (2.6.3)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from node2vec) (3.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from node2vec) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from node2vec) (4.62.3)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.7/dist-packages (from node2vec) (1.1.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim->node2vec) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim->node2vec) (1.4.1)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->node2vec) (5.2.1)
# Building wheels for collected packages: node2vec
#   Building wheel for node2vec (setup.py) ... done
#   Created wheel for node2vec: filename=node2vec-0.4.3-py3-none-any.whl size=5978 sha256=7358a2e298e32fe45957ca71505082a22f2ba6b5d5478113691a2e8358658f7e
#   Stored in directory: /root/.cache/pip/wheels/07/62/78/5202cb8c03cbf1593b48a8a442fca8ceec2a8c80e22318bae9
# Successfully built node2vec
# Installing collected packages: node2vec
# Successfully installed node2vec-0.4.3

# %%
import networkx as nx
from node2vec import Node2Vec
import pandas as pd
import regex as re
import nltk
from nltk.corpus import stopwords
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from nltk.stem.snowball import SnowballStemmer

# %%
news = pd.read_csv('https://raw.githubusercontent.com/Currie32/Predicting-the-Dow-Jones-with-Headlines/master/News.csv')
text_total = news.News
text_total = text_total.reset_index(drop=True)

# %%
text_total.head()
# Out:
# 0    A 117-year-old woman in Mexico City finally re...
# 1     IMF chief backs Athens as permanent Olympic host
# 2    The president of France says if Brexit won, so...
# 3    British Man Who Must Give Police 24 Hours' Not...
# 4    100+ Nobel laureates urge Greenpeace to stop o...
# Name: News, dtype: object

# %%
text_total = text_total.iloc[0:200]

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stemmer = SnowballStemmer("english")

# %%
# function to clean text
def review_to_words(raw_review):
    
    # 1. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", raw_review) 
    
    # 2. Convert to lower case, split into individual words
    words = letters_only.lower().split()
    
    # 3. Remove Stopwords. In Python, searching a set is much faster than searching a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    
    # 4. Remove stop words
    meaningful_words = [w for w in words if not w in stops]  #returns a list 
    # 5. Stem words. Need to define porter stemmer above
    singles = [stemmer.stem(word) for word in meaningful_words]
    
    # 7. remove remaining tokens that are not alphabetic
    singles = [word for word in singles if word.isalpha()]
    
    # 8. Join the words back into one string separated by space, and return the result.
    return( " ".join( singles ))

# %%
# apply it to our text data 
# dataset is named wine_data and the text are in the column "wmn"
processed_wmn = [ review_to_words(str(text)) for text in text_total]
print(processed_wmn[:5])
# Out:
# ['year old woman mexico citi final receiv birth certif die hour later trinidad alvarez lira wait year proof born', 'imf chief back athen perman olymp host', 'presid franc say brexit donald trump', 'british man must give polic hour notic sex threaten hunger strike man subject sexual risk order despit never convict crime', 'nobel laureat urg greenpeac stop oppos gmos']

# %%
processed_words = " ".join(processed_wmn).split()

# %%
def transform_sentences_to_pair_of_words(sentences):
    list_of_pair_of_words = []
    for i in range(len(sentences)):
        buffer_pair_of_words = (sentences[i-1],sentences[i])
        list_of_pair_of_words.append(buffer_pair_of_words)
    del list_of_pair_of_words[0]
    return list_of_pair_of_words

# %%
sentences_to_pair = transform_sentences_to_pair_of_words(processed_words)

# %%
sentences_to_pair
# Out:
# [('year', 'old'),
#  ('old', 'woman'),
#  ('woman', 'mexico'),
#  ('mexico', 'citi'),
#  ('citi', 'final'),
#  ('final', 'receiv'),
#  ('receiv', 'birth'),
#  ('birth', 'certif'),
#  ('certif', 'die'),
#  ('die', 'hour'),
#  ('hour', 'later'),
#  ('later', 'trinidad'),
#  ('trinidad', 'alvarez'),
#  ('alvarez', 'lira'),
#  ('lira', 'wait'),
#  ('wait', 'year'),
#  ('year', 'proof'),
#  ('proof', 'born'),
#  ('born', 'imf'),
#  ('imf', 'chief'),
#  ('chief', 'back'),
#  ('back', 'athen'),
#  ('athen', 'perman'),
#  ('perman', 'olymp'),
#  ('olymp', 'host'),
#  ('host', 'presid'),
#  ('presid', 'franc'),
#  ('franc', 'say'),
#  ('say', 'brexit'),
#  ('brexit', 'donald'),
#  ('donald', 'trump'),
#  ('trump', 'british'),
#  ('british', 'man'),
#  ('man', 'must'),
#  ('must', 'give'),
#  ('give', 'polic'),
#  ('polic', 'hour'),
#  ('hour', 'notic'),
#  ('notic', 'sex'),
#  ('sex', 'threaten'),
#  ('threaten', 'hunger'),
#  ('hunger', 'strike'),
#  ('strike', 'man'),
#  ('man', 'subject'),
#  ('subject', 'sexual'),
#  ('sexual', 'risk'),
#  ('risk', 'order'),
#  ('order', 'despit'),
#  ('despit', 'never'),
#  ('never', 'convict'),
#  ('convict', 'crime'),
#  ('crime', 'nobel'),
#  ('nobel', 'laureat'),
#  ('laureat', 'urg'),
#  ('urg', 'greenpeac'),
#  ('greenpeac', 'stop'),
#  ('stop', 'oppos'),
#  ('oppos', 'gmos'),
#  ('gmos', 'brazil'),
#  ('brazil', 'huge'),
#  ('huge', 'spike'),
#  ('spike', 'number'),
#  ('number', 'polic'),
#  ('polic', 'kill'),
#  ('kill', 'rio'),
#  ('rio', 'ahead'),
#  ('ahead', 'olymp'),
#  ('olymp', 'austria'),
#  ('austria', 'highest'),
#  ('highest', 'court'),
#  ('court', 'annul'),
#  ('annul', 'presidenti'),
#  ('presidenti', 'elect'),
#  ('elect', 'narrowli'),
#  ('narrowli', 'lost'),
#  ('lost', 'right'),
#  ('right', 'wing'),
#  ('wing', 'candid'),
#  ('candid', 'facebook'),
#  ('facebook', 'win'),
#  ('win', 'privaci'),
#  ('privaci', 'case'),
#  ('case', 'track'),
#  ('track', 'belgian'),
#  ('belgian', 'want'),
#  ('want', 'matter'),
#  ('matter', 'internet'),
#  ('internet', 'user'),
#  ('user', 'log'),
#  ('log', 'facebook'),
#  ('facebook', 'switzerland'),
#  ('switzerland', 'deni'),
#  ('deni', 'muslim'),
#  ('muslim', 'girl'),
#  ('girl', 'citizenship'),
#  ('citizenship', 'refus'),
#  ('refus', 'swim'),
#  ('swim', 'boy'),
#  ('boy', 'school'),
#  ('school', 'year'),
#  ('year', 'old'),
#  ('old', 'longer'),
#  ('longer', 'consid'),
#  ('consid', 'naturalis'),
#  ('naturalis', 'citizenship'),
#  ('citizenship', 'compli'),
#  ('compli', 'school'),
#  ('school', 'curriculum'),
#  ('curriculum', 'author'),
#  ('author', 'basel'),
#  ('basel', 'said'),
#  ('said', 'china'),
#  ('china', 'kill'),
#  ('kill', 'million'),
#  ('million', 'innoc'),
#  ('innoc', 'medit'),
#  ('medit', 'organ'),
#  ('organ', 'report'),
#  ('report', 'find'),
#  ('find', 'franc'),
#  ('franc', 'crack'),
#  ('crack', 'factori'),
#  ('factori', 'farm'),
#  ('farm', 'viral'),
#  ('viral', 'video'),
#  ('video', 'campaign'),
#  ('campaign', 'move'),
#  ('move', 'govt'),
#  ('govt', 'act'),
#  ('act', 'footag'),
#  ('footag', 'share'),
#  ('share', 'wide'),
#  ('wide', 'onlin'),
#  ('onlin', 'anim'),
#  ('anim', 'writh'),
#  ('writh', 'pain'),
#  ('pain', 'bleed'),
#  ('bleed', 'death'),
#  ('death', 'dismemb'),
#  ('dismemb', 'violat'),
#  ('violat', 'rule'),
#  ('rule', 'requir'),
#  ('requir', 'render'),
#  ('render', 'unconsci'),
#  ('unconsci', 'slaughter'),
#  ('slaughter', 'abba'),
#  ('abba', 'plo'),
#  ('plo', 'faction'),
#  ('faction', 'call'),
#  ('call', 'killer'),
#  ('killer', 'year'),
#  ('year', 'old'),
#  ('old', 'american'),
#  ('american', 'isra'),
#  ('isra', 'girl'),
#  ('girl', 'martyr'),
#  ('martyr', 'taiwanes'),
#  ('taiwanes', 'warship'),
#  ('warship', 'accident'),
#  ('accident', 'fire'),
#  ('fire', 'missil'),
#  ('missil', 'toward'),
#  ('toward', 'china'),
#  ('china', 'iran'),
#  ('iran', 'celebr'),
#  ('celebr', 'american'),
#  ('american', 'human'),
#  ('human', 'right'),
#  ('right', 'week'),
#  ('week', 'mock'),
#  ('mock', 'u'),
#  ('u', 'right'),
#  ('right', 'record'),
#  ('record', 'u'),
#  ('u', 'n'),
#  ('n', 'panel'),
#  ('panel', 'move'),
#  ('move', 'curb'),
#  ('curb', 'bias'),
#  ('bias', 'l'),
#  ('l', 'g'),
#  ('g', 'b'),
#  ('b', 'peopl'),
#  ('peopl', 'despit'),
#  ('despit', 'fierc'),
#  ('fierc', 'resist'),
#  ('resist', 'muslim'),
#  ('muslim', 'african'),
#  ('african', 'countri'),
#  ('countri', 'unit'),
#  ('unit', 'state'),
#  ('state', 'place'),
#  ('place', 'myanmar'),
#  ('myanmar', 'uzbekistan'),
#  ('uzbekistan', 'sudan'),
#  ('sudan', 'haiti'),
#  ('haiti', 'list'),
#  ('list', 'worst'),
#  ('worst', 'human'),
#  ('human', 'traffick'),
#  ('traffick', 'offend'),
#  ('offend', 'amp'),
#  ('amp', 'p'),
#  ('p', 'revis'),
#  ('revis', 'european'),
#  ('european', 'union'),
#  ('union', 'credit'),
#  ('credit', 'rate'),
#  ('rate', 'aa'),
#  ('aa', 'aa'),
#  ('aa', 'india'),
#  ('india', 'get'),
#  ('get', 'billion'),
#  ('billion', 'loan'),
#  ('loan', 'world'),
#  ('world', 'bank'),
#  ('bank', 'solar'),
#  ('solar', 'mission'),
#  ('mission', 'u'),
#  ('u', 'sailor'),
#  ('sailor', 'detain'),
#  ('detain', 'iran'),
#  ('iran', 'spoke'),
#  ('spoke', 'much'),
#  ('much', 'interrog'),
#  ('interrog', 'navi'),
#  ('navi', 'mass'),
#  ('mass', 'fish'),
#  ('fish', 'kill'),
#  ('kill', 'vietnam'),
#  ('vietnam', 'solv'),
#  ('solv', 'taiwan'),
#  ('taiwan', 'steelmak'),
#  ('steelmak', 'accept'),
#  ('accept', 'respons'),
#  ('respons', 'pollut'),
#  ('pollut', 'philippin'),
#  ('philippin', 'presid'),
#  ('presid', 'rodrigo'),
#  ('rodrigo', 'dutert'),
#  ('dutert', 'urg'),
#  ('urg', 'peopl'),
#  ('peopl', 'kill'),
#  ('kill', 'drug'),
#  ('drug', 'addict'),
#  ('addict', 'dutert'),
#  ('dutert', 'power'),
#  ('power', 'landslid'),
#  ('landslid', 'campaign'),
#  ('campaign', 'domin'),
#  ('domin', 'threat'),
#  ('threat', 'kill'),
#  ('kill', 'ten'),
#  ('ten', 'thousand'),
#  ('thousand', 'war'),
#  ('war', 'crime'),
#  ('crime', 'spain'),
#  ('spain', 'arrest'),
#  ('arrest', 'three'),
#  ('three', 'pakistani'),
#  ('pakistani', 'accus'),
#  ('accus', 'promot'),
#  ('promot', 'milit'),
#  ('milit', 'venezuela'),
#  ('venezuela', 'anger'),
#  ('anger', 'food'),
#  ('food', 'shortag'),
#  ('shortag', 'still'),
#  ('still', 'mount'),
#  ('mount', 'continu'),
#  ('continu', 'roil'),
#  ('roil', 'week'),
#  ('week', 'angri'),
#  ('angri', 'protest'),
#  ('protest', 'break'),
#  ('break', 'in'),
#  ('in', 'groceri'),
#  ('groceri', 'store'),
#  ('store', 'busi'),
#  ('busi', 'left'),
#  ('left', 'five'),
#  ('five', 'dead'),
#  ('dead', 'least'),
#  ('least', 'injur'),
#  ('injur', 'arrest'),
#  ('arrest', 'accord'),
#  ('accord', 'various'),
#  ('various', 'news'),
#  ('news', 'report'),
#  ('report', 'hindu'),
#  ('hindu', 'templ'),
#  ('templ', 'worker'),
#  ('worker', 'kill'),
#  ('kill', 'three'),
#  ('three', 'men'),
#  ('men', 'motorcycl'),
#  ('motorcycl', 'local'),
#  ('local', 'polic'),
#  ('polic', 'said'),
#  ('said', 'peopl'),
#  ('peopl', 'kill'),
#  ('kill', 'attack'),
#  ('attack', 'blame'),
#  ('blame', 'islamist'),
#  ('islamist', 'milit'),
#  ('milit', 'bangladesh'),
#  ('bangladesh', 'sinc'),
#  ('sinc', 'februari'),
#  ('februari', 'includ'),
#  ('includ', 'secular'),
#  ('secular', 'blogger'),
#  ('blogger', 'academ'),
#  ('academ', 'gay'),
#  ('gay', 'right'),
#  ('right', 'activist'),
#  ('activist', 'member'),
#  ('member', 'religi'),
#  ('religi', 'minor'),
#  ('minor', 'ozon'),
#  ('ozon', 'layer'),
#  ('layer', 'hole'),
#  ('hole', 'seem'),
#  ('seem', 'heal'),
#  ('heal', 'us'),
#  ('us', 'amp'),
#  ('amp', 'uk'),
#  ('uk', 'team'),
#  ('team', 'show'),
#  ('show', 'shrunk'),
#  ('shrunk', 'amp'),
#  ('amp', 'may'),
#  ('may', 'slowli'),
#  ('slowli', 'recov'),
#  ('recov', 'ozon'),
#  ('ozon', 'hole'),
#  ('hole', 'anywher'),
#  ('anywher', 'world'),
#  ('world', 'antarctica'),
#  ('antarctica', 'teem'),
#  ('teem', 'life'),
#  ('life', 'show'),
#  ('show', 'us'),
#  ('us', 'didnt'),
#  ('didnt', 'back'),
#  ('back', 'chemic'),
#  ('chemic', 'wed'),
#  ('wed', 'crisi'),
#  ('crisi', 'jamaica'),
#  ('jamaica', 'propos'),
#  ('propos', 'marijuana'),
#  ('marijuana', 'dispens'),
#  ('dispens', 'tourist'),
#  ('tourist', 'airport'),
#  ('airport', 'follow'),
#  ('follow', 'legalis'),
#  ('legalis', 'kiosk'),
#  ('kiosk', 'desk'),
#  ('desk', 'would'),
#  ('would', 'give'),
#  ('give', 'peopl'),
#  ('peopl', 'licens'),
#  ('licens', 'purchas'),
#  ('purchas', 'ounc'),
#  ('ounc', 'drug'),
#  ('drug', 'use'),
#  ('use', 'stay'),
#  ('stay', 'stephen'),
#  ('stephen', 'hawk'),
#  ('hawk', 'say'),
#  ('say', 'pollut'),
#  ('pollut', 'stupid'),
#  ('stupid', 'still'),
#  ('still', 'biggest'),
#  ('biggest', 'threat'),
#  ('threat', 'mankind'),
#  ('mankind', 'certain'),
#  ('certain', 'becom'),
#  ('becom', 'less'),
#  ('less', 'greedi'),
#  ('greedi', 'less'),
#  ('less', 'stupid'),
#  ('stupid', 'treatment'),
#  ('treatment', 'environ'),
#  ('environ', 'past'),
#  ('past', 'decad'),
#  ('decad', 'bori'),
#  ('bori', 'johnson'),
#  ('johnson', 'say'),
#  ('say', 'run'),
#  ('run', 'tori'),
#  ('tori', 'parti'),
#  ('parti', 'leadership'),
#  ('leadership', 'six'),
#  ('six', 'gay'),
#  ('gay', 'men'),
#  ('men', 'ivori'),
#  ('ivori', 'coast'),
#  ('coast', 'abus'),
#  ('abus', 'forc'),
#  ('forc', 'flee'),
#  ('flee', 'home'),
#  ('home', 'pictur'),
#  ('pictur', 'sign'),
#  ('sign', 'condol'),
#  ('condol', 'book'),
#  ('book', 'victim'),
#  ('victim', 'recent'),
#  ('recent', 'attack'),
#  ('attack', 'gay'),
#  ('gay', 'nightclub'),
#  ('nightclub', 'florida'),
#  ('florida', 'switzerland'),
#  ('switzerland', 'deni'),
#  ('deni', 'citizenship'),
#  ('citizenship', 'muslim'),
#  ('muslim', 'immigr'),
#  ('immigr', 'girl'),
#  ('girl', 'refus'),
#  ('refus', 'swim'),
#  ('swim', 'boy'),
#  ('boy', 'report'),
#  ('report', 'palestinian'),
#  ('palestinian', 'terrorist'),
#  ('terrorist', 'stab'),
#  ('stab', 'isra'),
#  ('isra', 'teen'),
#  ('teen', 'girl'),
#  ('girl', 'death'),
#  ('death', 'bedroom'),
#  ('bedroom', 'puerto'),
#  ('puerto', 'rico'),
#  ('rico', 'default'),
#  ('default', 'billion'),
#  ('billion', 'debt'),
#  ('debt', 'friday'),
#  ('friday', 'republ'),
#  ('republ', 'ireland'),
#  ('ireland', 'fan'),
#  ('fan', 'award'),
#  ('award', 'medal'),
#  ('medal', 'sportsmanship'),
#  ('sportsmanship', 'pari'),
#  ('pari', 'mayor'),
#  ('mayor', 'afghan'),
#  ('afghan', 'suicid'),
#  ('suicid', 'bomber'),
#  ('bomber', 'kill'),
#  ('kill', 'bbc'),
#  ('bbc', 'news'),
#  ('news', 'us'),
#  ('us', 'airstrik'),
#  ('airstrik', 'kill'),
#  ('kill', 'least'),
#  ('least', 'isi'),
#  ('isi', 'fighter'),
#  ('fighter', 'convoy'),
#  ('convoy', 'outsid'),
#  ('outsid', 'fallujah'),
#  ('fallujah', 'offici'),
#  ('offici', 'say'),
#  ('say', 'turkish'),
#  ('turkish', 'cop'),
#  ('cop', 'took'),
#  ('took', 'istanbul'),
#  ('istanbul', 'gunman'),
#  ('gunman', 'hail'),
#  ('hail', 'hero'),
#  ('hero', 'cannabi'),
#  ('cannabi', 'compound'),
#  ('compound', 'could'),
#  ('could', 'treat'),
#  ('treat', 'alzheim'),
#  ('alzheim', 'remov'),
#  ('remov', 'plaqu'),
#  ('plaqu', 'form'),
#  ('form', 'protein'),
#  ('protein', 'brain'),
#  ('brain', 'cell'),
#  ('cell', 'research'),
#  ('research', 'suggest'),
#  ('suggest', 'japan'),
#  ('japan', 'top'),
#  ('top', 'court'),
#  ('court', 'approv'),
#  ('approv', 'blanket'),
#  ('blanket', 'surveil'),
#  ('surveil', 'countri'),
#  ('countri', 'muslim'),
#  ('muslim', 'made'),
#  ('made', 'us'),
#  ('us', 'terrorist'),
#  ('terrorist', 'suspect'),
#  ('suspect', 'never'),
#  ('never', 'anyth'),
#  ('anyth', 'wrong'),
#  ('wrong', 'say'),
#  ('say', 'japanes'),
#  ('japanes', 'muslim'),
#  ('muslim', 'moham'),
#  ('moham', 'fujita'),
#  ('fujita', 'cia'),
#  ('cia', 'gave'),
#  ('gave', 'romania'),
#  ('romania', 'million'),
#  ('million', 'host'),
#  ('host', 'secret'),
#  ('secret', 'prison'),
#  ('prison', 'group'),
#  ('group', 'urg'),
#  ('urg', 'u'),
#  ('u', 'n'),
#  ('n', 'suspend'),
#  ('suspend', 'saudi'),
#  ('saudi', 'arabia'),
#  ('arabia', 'right'),
#  ('right', 'council'),
#  ('council', 'googl'),
#  ('googl', 'free'),
#  ('free', 'wifi'),
#  ('wifi', 'indian'),
#  ('indian', 'railway'),
#  ('railway', 'station'),
#  ('station', 'better'),
#  ('better', 'countri'),
#  ('countri', 'paid'),
#  ('paid', 'servic'),
#  ('servic', 'mount'),
#  ('mount', 'evid'),
#  ('evid', 'suggest'),
#  ('suggest', 'hobbit'),
#  ('hobbit', 'wipe'),
#  ('wipe', 'modern'),
#  ('modern', 'human'),
#  ('human', 'ancestor'),
#  ('ancestor', 'year'),
#  ('year', 'ago'),
#  ('ago', 'men'),
#  ('men', 'carri'),
#  ('carri', 'tuesday'),
#  ('tuesday', 'terror'),
#  ('terror', 'attack'),
#  ('attack', 'istanbul'),
#  ('istanbul', 'ataturk'),
#  ('ataturk', 'airport'),
#  ('airport', 'russia'),
#  ('russia', 'uzbekistan'),
#  ('uzbekistan', 'kyrgyzstan'),
#  ('kyrgyzstan', 'turkish'),
#  ('turkish', 'offic'),
#  ('offic', 'said'),
#  ('said', 'call'),
#  ('call', 'suspend'),
#  ('suspend', 'saudi'),
#  ('saudi', 'arabia'),
#  ('arabia', 'un'),
#  ('un', 'human'),
#  ('human', 'right'),
#  ('right', 'council'),
#  ('council', 'militari'),
#  ('militari', 'aggres'),
#  ('aggres', 'yemen'),
#  ('yemen', 'nobel'),
#  ('nobel', 'laureat'),
#  ('laureat', 'call'),
#  ('call', 'greenpeac'),
#  ('greenpeac', 'anti'),
#  ('anti', 'gmo'),
#  ('gmo', 'obstruct'),
#  ('obstruct', 'develop'),
#  ('develop', 'world'),
#  ('world', 'british'),
#  ('british', 'pedophil'),
#  ('pedophil', 'sentenc'),
#  ('sentenc', 'year'),
#  ('year', 'us'),
#  ('us', 'traffick'),
#  ('traffick', 'child'),
#  ('child', 'abus'),
#  ('abus', 'imag'),
#  ('imag', 'domminich'),
#  ('domminich', 'shaw'),
#  ('shaw', 'kingpin'),
#  ('kingpin', 'sexual'),
#  ('sexual', 'violenc'),
#  ('violenc', 'children'),
#  ('children', 'sent'),
#  ('sent', 'dozen'),
#  ('dozen', 'imag'),
#  ('imag', 'onlin'),
#  ('onlin', 'discuss'),
#  ('discuss', 'plan'),
#  ('plan', 'assault'),
#  ('assault', 'kill'),
#  ('kill', 'child'),
#  ('child', 'probat'),
#  ('probat', 'us'),
#  ('us', 'permit'),
#  ('permit', 'offshor'),
#  ('offshor', 'frack'),
#  ('frack', 'gulf'),
#  ('gulf', 'mexico'),
#  ('mexico', 'allow'),
#  ('allow', 'billion'),
#  ('billion', 'gallon'),
#  ('gallon', 'chemic'),
#  ('chemic', 'discharg'),
#  ('discharg', 'swim'),
#  ('swim', 'ridicul'),
#  ('ridicul', 'french'),
#  ('french', 'beach'),
#  ('beach', 'polic'),
#  ('polic', 'carri'),
#  ('carri', 'gun'),
#  ('gun', 'swim'),
#  ('swim', 'trunk'),
#  ('trunk', 'polic'),
#  ('polic', 'lifeguard'),
#  ('lifeguard', 'franc'),
#  ('franc', 'busiest'),
#  ('busiest', 'beach'),
#  ('beach', 'carri'),
#  ('carri', 'gun'),
#  ('gun', 'bullet'),
#  ('bullet', 'proof'),
#  ('proof', 'vest'),
#  ('vest', 'first'),
#  ('first', 'time'),
#  ('time', 'summer'),
#  ('summer', 'amid'),
#  ('amid', 'fear'),
#  ('fear', 'terrorist'),
#  ('terrorist', 'could'),
#  ('could', 'target'),
#  ('target', 'holidaymak'),
#  ('holidaymak', 'uefa'),
#  ('uefa', 'say'),
#  ('say', 'minut'),
#  ('minut', 'silenc'),
#  ('silenc', 'istanbul'),
#  ('istanbul', 'victim'),
#  ('victim', 'euro'),
#  ('euro', 'turkey'),
#  ('turkey', 'alreadi'),
#  ('alreadi', 'elimin'),
#  ('elimin', 'law'),
#  ('law', 'enforc'),
#  ('enforc', 'sourc'),
#  ('sourc', 'gun'),
#  ('gun', 'use'),
#  ('use', 'pari'),
#  ('pari', 'terrorist'),
#  ('terrorist', 'attack'),
#  ('attack', 'came'),
#  ('came', 'phoenix'),
#  ('phoenix', 'explos'),
#  ('explos', 'airport'),
#  ('airport', 'istanbul'),
#  ('istanbul', 'yemeni'),
#  ('yemeni', 'former'),
#  ('former', 'presid'),
#  ('presid', 'terror'),
#  ('terror', 'offspr'),
#  ('offspr', 'wahhab'),
#  ('wahhab', 'al'),
#  ('al', 'saud'),
#  ('saud', 'regim'),
#  ('regim', 'uk'),
#  ('uk', 'must'),
#  ('must', 'accept'),
#  ('accept', 'freedom'),
#  ('freedom', 'movement'),
#  ('movement', 'access'),
#  ('access', 'eu'),
#  ('eu', 'market'),
#  ('market', 'devast'),
#  ('devast', 'scientist'),
#  ('scientist', 'late'),
#  ('late', 'captiv'),
#  ('captiv', 'breed'),
#  ('breed', 'mammal'),
#  ('mammal', 'lost'),
#  ('lost', 'climat'),
#  ('climat', 'chang'),
#  ('chang', 'australian'),
#  ('australian', 'conservationist'),
#  ('conservationist', 'spent'),
#  ('spent', 'month'),
#  ('month', 'obtain'),
#  ('obtain', 'permiss'),
#  ('permiss', 'amp'),
#  ('amp', 'plan'),
#  ('plan', 'captiv'),
#  ('captiv', 'breed'),
#  ('breed', 'program'),
#  ('program', 'arriv'),
#  ('arriv', 'rodent'),
#  ('rodent', 'tini'),
#  ('tini', 'island'),
#  ('island', 'late'),
#  ('late', 'british'),
#  ('british', 'labor'),
#  ('labor', 'parti'),
#  ('parti', 'leader'),
#  ('leader', 'jeremi'),
#  ('jeremi', 'corbyn'),
#  ('corbyn', 'lose'),
#  ('lose', 'confid'),
#  ('confid', 'vote'),
#  ('vote', 'refus'),
#  ('refus', 'resign'),
#  ('resign', 'muslim'),
#  ('muslim', 'shop'),
#  ('shop', 'uk'),
#  ('uk', 'firebomb'),
#  ('firebomb', 'peopl'),
#  ('peopl', 'insid'),
#  ('insid', 'mexican'),
#  ('mexican', 'author'),
#  ('author', 'sexual'),
#  ('sexual', 'tortur'),
#  ('tortur', 'women'),
#  ('women', 'prison'),
#  ('prison', 'uk'),
#  ('uk', 'share'),
#  ('share', 'pound'),
#  ('pound', 'continu'),
#  ('continu', 'recov'),
#  ('recov', 'iceland'),
#  ('iceland', 'historian'),
#  ('historian', 'johannesson'),
#  ('johannesson', 'win'),
#  ('win', 'presidenti'),
#  ('presidenti', 'elect'),
#  ('elect', 'million'),
#  ('million', 'yr'),
#  ('yr', 'old'),
#  ('old', 'bird'),
#  ('bird', 'wing'),
#  ('wing', 'found'),
#  ('found', 'encas'),
#  ('encas', 'amber'),
#  ('amber', 'find'),
#  ('find', 'thing'),
#  ('thing', 'trap'),
#  ('trap', 'amber'),
#  ('amber', 'far'),
#  ('far', 'rare'),
#  ('rare', 'research'),
#  ('research', 'burma'),
#  ('burma', 'found'),
#  ('found', 'pair'),
#  ('pair', 'tini'),
#  ('tini', 'bird'),
#  ('bird', 'like'),
#  ('like', 'wing'),
#  ('wing', 'frozen'),
#  ('frozen', 'insid'),
#  ('insid', 'knew'),
#  ('knew', 'someth'),
#  ('someth', 'special'),
#  ('special', 'chatbot'),
#  ('chatbot', 'program'),
#  ('program', 'british'),
#  ('british', 'teenag'),
#  ('teenag', 'success'),
#  ('success', 'challeng'),
#  ('challeng', 'park'),
#  ('park', 'ticket'),
#  ('ticket', 'sinc'),
#  ('sinc', 'launch'),
#  ('launch', 'last'),
#  ('last', 'year'),
#  ('year', 'philippin'),
#  ('philippin', 'presid'),
#  ('presid', 'elect'),
#  ('elect', 'said'),
#  ('said', 'monday'),
#  ('monday', 'would'),
#  ('would', 'aggress'),
#  ('aggress', 'promot'),
#  ('promot', 'artifici'),
#  ('artifici', 'birth'),
#  ('birth', 'control'),
#  ('control', 'countri'),
#  ('countri', 'even'),
#  ('even', 'risk'),
#  ('risk', 'get'),
#  ('get', 'fight'),
#  ('fight', 'domin'),
#  ('domin', 'cathol'),
#  ('cathol', 'church'),
#  ('church', 'staunch'),
#  ('staunch', 'oppos'),
#  ('oppos', 'use'),
#  ('use', 'contracept'),
#  ('contracept', 'former'),
#  ('former', 'belgian'),
#  ('belgian', 'prime'),
#  ('prime', 'minist'),
#  ('minist', 'ridicul'),
#  ('ridicul', 'nigel'),
#  ('nigel', 'farag'),
#  ('farag', 'accus'),
#  ('accus', 'ukip'),
#  ('ukip', 'leader'),
#  ('leader', 'lie'),
#  ('lie', 'eu'),
#  ('eu', 'referendum'),
#  ('referendum', 'campaign'),
#  ('campaign', 'brexit'),
#  ('brexit', 'nigel'),
#  ('nigel', 'farag'),
#  ('farag', 'eu'),
#  ('eu', 'laugh'),
#  ('laugh', 'islam'),
#  ('islam', 'state'),
#  ('state', 'bomb'),
#  ('bomb', 'southern'),
#  ('southern', 'yemen'),
#  ('yemen', 'kill'),
#  ('kill', 'peopl'),
#  ('peopl', 'escap'),
#  ('escap', 'tunnel'),
#  ('tunnel', 'dug'),
#  ('dug', 'hand'),
#  ('hand', 'found'),
#  ('found', 'holocaust'),
#  ('holocaust', 'massacr'),
#  ('massacr', 'site'),
#  ('site', 'land'),
#  ('land', 'beij'),
#  ('beij', 'sink'),
#  ('sink', 'much'),
#  ('much', 'four'),
#  ('four', 'inch'),
#  ('inch', 'per'),
#  ('per', 'year'),
#  ('year', 'overconsumpt'),
#  ('overconsumpt', 'groundwat'),
#  ('groundwat', 'accord'),
#  ('accord', 'new'),
#  ('new', 'research'),
#  ('research', 'car'),
#  ('car', 'bomb'),
#  ('bomb', 'anti'),
#  ('anti', 'islam'),
#  ('islam', 'attack'),
#  ('attack', 'mosqu'),
#  ('mosqu', 'perth'),
#  ('perth', 'australia'),
#  ('australia', 'emaci'),
#  ('emaci', 'lion'),
#  ('lion', 'taiz'),
#  ('taiz', 'zoo'),
#  ('zoo', 'trap'),
#  ('trap', 'blood'),
#  ('blood', 'soak'),
#  ('soak', 'cage'),
#  ('cage', 'left'),
#  ('left', 'starv'),
#  ('starv', 'month'),
#  ('month', 'due'),
#  ('due', 'yemeni'),
#  ('yemeni', 'civil'),
#  ('civil', 'war'),
#  ('war', 'rupert'),
#  ('rupert', 'murdoch'),
#  ('murdoch', 'describ'),
#  ('describ', 'brexit'),
#  ('brexit', 'wonder'),
#  ('wonder', 'media'),
#  ('media', 'mogul'),
#  ('mogul', 'liken'),
#  ('liken', 'leav'),
#  ('leav', 'eu'),
#  ('eu', 'prison'),
#  ('prison', 'break'),
#  ('break', 'share'),
#  ('share', 'view'),
#  ('view', 'donald'),
#  ('donald', 'trump'),
#  ('trump', 'abl'),
#  ('abl', 'man'),
#  ('man', 'kill'),
#  ('kill', 'yemen'),
#  ('yemen', 'suicid'),
#  ('suicid', 'attack'),
#  ('attack', 'googl'),
#  ('googl', 'found'),
#  ('found', 'disastr'),
#  ('disastr', 'symantec'),
#  ('symantec', 'norton'),
#  ('norton', 'vulner'),
#  ('vulner', 'bad'),
#  ('bad', 'get'),
#  ('get', 'extremist'),
#  ('extremist', 'violenc'),
#  ('violenc', 'rise'),
#  ('rise', 'germani'),
#  ('germani', 'domest'),
#  ('domest', 'intellig'),
#  ('intellig', 'agenc'),
#  ('agenc', 'say'),
#  ('say', 'far'),
#  ('far', 'right'),
#  ('right', 'far'),
#  ('far', 'left'),
#  ('left', 'islamist'),
#  ('islamist', 'radic'),
#  ('radic', 'group'),
#  ('group', 'gain'),
#  ('gain', 'membership'),
#  ('membership', 'countri'),
#  ('countri', 'bbc'),
#  ('bbc', 'news'),
#  ('news', 'labour'),
#  ('labour', 'mps'),
#  ('mps', 'pass'),
#  ('pass', 'corbyn'),
#  ('corbyn', 'confid'),
#  ('confid', 'motion'),
#  ('motion', 'tini'),
#  ('tini', 'new'),
#  ('new', 'zealand'),
#  ('zealand', 'town'),
#  ('town', 'mani'),
#  ('mani', 'job'),
#  ('job', 'launch'),
#  ('launch', 'drive'),
#  ('drive', 'recruit'),
#  ('recruit', 'outsid'),
#  ('outsid', 'scientist'),
#  ('scientist', 'australia'),
#  ('australia', 'want'),
#  ('want', 'save'),
#  ('save', 'great'),
#  ('great', 'barrier'),
#  ('barrier', 'reef'),
#  ('reef', 'stop'),
#  ('stop', 'support'),
#  ('support', 'coal'),
#  ('coal', 'person'),
#  ('person', 'detail'),
#  ('detail', 'french'),
#  ('french', 'polic'),
#  ('polic', 'offic'),
#  ('offic', 'upload'),
#  ('upload', 'googl'),
#  ('googl', 'drive'),
#  ('drive', 'secur'),
#  ('secur', 'breach'),
#  ('breach', 'fortnight'),
#  ('fortnight', 'two'),
#  ('two', 'offic'),
#  ('offic', 'murder'),
#  ('murder', 'home'),
#  ('home', 'jihadist'),
#  ('jihadist', 'amp'),
#  ('amp', 'p'),
#  ('p', 'cut'),
#  ('cut', 'unit'),
#  ('unit', 'kingdom'),
#  ('kingdom', 'sovereign'),
#  ('sovereign', 'credit'),
#  ('credit', 'rate'),
#  ('rate', 'aa'),
#  ('aa', 'aaa'),
#  ('aaa', 'huge'),
#  ('huge', 'helium'),
#  ('helium', 'deposit'),
#  ('deposit', 'found'),
#  ('found', 'africa'),
#  ('africa', 'ceo'),
#  ('ceo', 'south'),
#  ('south', 'african'),
#  ('african', 'state'),
#  ('state', 'broadcast'),
#  ('broadcast', 'quit'),
#  ('quit', 'short'),
#  ('short', 'negat'),
#  ('negat', 'news'),
#  ('news', 'presid'),
#  ('presid', 'ban'),
#  ('ban', 'brexit'),
#  ('brexit', 'cost'),
#  ('cost', 'investor'),
#  ('investor', 'trillion'),
#  ('trillion', 'worst'),
#  ('worst', 'one'),
#  ('one', 'day'),
#  ('day', 'drop'),
#  ('drop', 'ever'),
#  ('ever', 'hong'),
#  ('hong', 'kong'),
#  ('kong', 'democraci'),
#  ('democraci', 'activist'),
#  ('activist', 'call'),
#  ('call', 'return'),
#  ('return', 'british'),
#  ('british', 'rule'),
#  ...]

# %%
G = nx.DiGraph()
G.add_edges_from(sentences_to_pair)
G = G.to_undirected()

# %%
print(type(G))
# Out:
# <class 'networkx.classes.graph.Graph'>

# %%
node2vec = Node2Vec(G, dimensions=20, walk_length=16, num_walks=100, workers=2)
# Out:
# Computing transition probabilities:   0%|          | 0/1199 [00:00<?, ?it/s]

# %%
model = node2vec.fit(window=10, min_count=1)

# %%
for node, _ in model.most_similar('trump'):
  if len(node) > 3:
    print(node)
# Out:
# donald
# caus
# british
# commission
# teenag
# politician
# half
# view
# though
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.

# %%
import numpy as np

player_nodes = [x for x in model.wv.vocab if len(x) > 3]
embeddings = np.array([model.wv[x] for x in player_nodes])

# %%
embeddings
# Out:
# array([[ 1.2062219 , -0.41281733,  1.1811962 , ...,  0.72622854,
#          0.55886644,  0.5049569 ],
#        [ 1.3934379 , -0.28094143,  1.4903531 , ...,  0.6336134 ,
#          0.48334023,  0.9164011 ],
#        [ 1.5081961 , -1.0063561 ,  1.3517443 , ...,  0.14185488,
#          0.34594718,  0.18243645],
#        ...,
#        [ 0.81489366,  0.55776596,  0.2367249 , ...,  0.46365878,
#         -0.14924149,  0.33605748],
#        [ 0.09426497,  1.3750246 ,  2.0772178 , ...,  1.211369  ,
#         -0.39201933, -0.21287772],
#        [ 0.02672489, -0.25935072,  0.01373101, ..., -0.5546028 ,
#         -0.90450835,  0.40794232]], dtype=float32)

# %%
def tsne_plot(model):
  "Creates and TSNE model and plots it"
  labels = []
  tokens = []

  for word in model.wv.vocab:
    tokens.append(model[word])
    labels.append(word)

  tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
  new_values = tsne_model.fit_transform(tokens)

  x = []
  y = []
  for value in new_values:
    x.append(value[0])
    y.append(value[1])

  plt.figure(figsize=(16, 16)) 
  for i in range(len(x)):
    plt.scatter(x[i],y[i])
    plt.annotate(labels[i],
              xy=(x[i], y[i]),
              xytext=(5, 2),
              textcoords='offset points',
              ha='right',
              va='bottom')
  plt.show()

# %%
tsne_plot(model)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,

# %%
pip install pyvis
# Out:
# Collecting pyvis
#   Downloading pyvis-0.1.9-py3-none-any.whl (23 kB)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.7/dist-packages (from pyvis) (2.6.3)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from pyvis) (5.5.0)
# Collecting jsonpickle>=1.4.1
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.7/dist-packages (from pyvis) (2.11.3)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (0.8.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (57.4.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (1.0.18)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.9.6->pyvis) (2.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonpickle>=1.4.1->pyvis) (4.8.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.3.0->pyvis) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.3.0->pyvis) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonpickle>=1.4.1->pyvis) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonpickle>=1.4.1->pyvis) (3.10.0.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython>=5.3.0->pyvis) (0.7.0)
# Installing collected packages: jsonpickle, pyvis
# Successfully installed jsonpickle-2.0.0 pyvis-0.1.9

# %%
from pyvis.network import Network

# %%
nt = Network('1024px', '1024px')

# %%
nt.from_nx(G)

# %%
nt.show('nx4.html')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
